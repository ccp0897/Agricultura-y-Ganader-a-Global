# %% [markdown]
# # Comprobación de que datos tenemos antes de comenzar con el ETL y EDA

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### 1. Datos estructurados

# %%
df_agricola = pd.read_csv('datos/produccion_agricola.csv')
df_agricola.head()
# Out:
#         pais codigo_iso           region  cultivo  anio  superficie_hectareas  \
# 0  Argentina        ARG  América del Sur     Soja  2011               4703643
# 1  Argentina        ARG  América del Sur     Maíz  2011               3371781
# 2  Argentina        ARG  América del Sur   Cebada  2011               1661577
# 3  Argentina        ARG  América del Sur       Té  2011                188518
# 4  Argentina        ARG  América del Sur  Algodón  2011               1638327
#
#    rendimiento_ton_ha  produccion_ton  fertilizantes_kg_ha  agua_riego_m3_ha  \
# 0                2.22        10465461                  105              4811
# 1                8.45        28485921                  164              5557
# 2                2.77         4596917                  105              6514
# 3                3.07          577886                  236              8527
# 4                1.18         1929756                  276              6925
#
#    tendencia_5_anios
# ...

# %%
df_agricola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   pais                  1200 non-null   object
#  1   codigo_iso            1200 non-null   object
#  2   region                1200 non-null   object
#  3   cultivo               1200 non-null   object
#  4   anio                  1200 non-null   int64
#  5   superficie_hectareas  1200 non-null   int64
#  6   rendimiento_ton_ha    1200 non-null   float64
#  7   produccion_ton        1200 non-null   int64
#  8   fertilizantes_kg_ha   1200 non-null   int64
#  9   agua_riego_m3_ha      1200 non-null   int64
#  10  tendencia_5_anios     1200 non-null   float64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 103.3+ KB

# %%
df_ganadera = pd.read_csv('datos/produccion_ganadera.csv')
df_ganadera.head()
# Out:
#         pais  anio tipo_ganado  cabezas_ganado  produccion_carne_ton  \
# 0  Argentina  2011      bovino        18160590               1857394
# 1  Argentina  2011     porcino        13481224               1528896
# 2  Argentina  2011     avicola       979196737               1290153
# 3  Argentina  2011       ovino        13789178                477282
# 4  Argentina  2011     caprino         2045715                345732
#
#    produccion_leche_lt  emisiones_ch4_ton_co2eq  intensidad_emisiones  \
# 0           2355425160                  1121740                 0.062
# 1                    0                  1984357                 0.147
# 2                    0                 10160819                 0.010
# 3            329191349                  5061273                 0.367
# 4            454558689                   284966                 0.139
#
#    eficiencia_carne
# 0            0.1023
# 1            0.1134
# 2            0.0013
# 3            0.0346
# 4            0.1690

# %%
df_ganadera.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   pais                     600 non-null    object
#  1   anio                     600 non-null    int64
#  2   tipo_ganado              600 non-null    object
#  3   cabezas_ganado           600 non-null    int64
#  4   produccion_carne_ton     600 non-null    int64
#  5   produccion_leche_lt      600 non-null    int64
#  6   emisiones_ch4_ton_co2eq  600 non-null    int64
#  7   intensidad_emisiones     600 non-null    float64
#  8   eficiencia_carne         600 non-null    float64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 42.3+ KB

# %%
df_precio = pd.read_csv('datos/precios_mercado.csv')
df_precio.head()
# Out:
#         fecha       pais      producto  precio_usd_ton  volumen_operado_ton  \
# 0  2021-01-01  Argentina  Carne_bovina         4299.14               127922
# 1  2021-01-01  Argentina         Arroz          330.04                73231
# 2  2021-01-01  Argentina          Maíz          210.36                11666
# 3  2021-01-01     Brasil          Maíz          212.91               195579
# 4  2021-01-01     Brasil         Leche          356.41               136137
#
#   tendencia_30_dias mercado_principal  precio_min_mes  precio_max_mes
# 0          subiendo                UE         3844.74         4517.42
# 1          subiendo  Sudeste Asiático          310.10          359.86
# 2           bajando             Japón          200.56          238.83
# 3          subiendo     Oriente Medio          200.25          243.04
# 4          subiendo                UE          348.39          390.03

# %%
df_precio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 864 entries, 0 to 863
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   fecha                864 non-null    object
#  1   pais                 864 non-null    object
#  2   producto             864 non-null    object
#  3   precio_usd_ton       864 non-null    float64
#  4   volumen_operado_ton  864 non-null    int64
#  5   tendencia_30_dias    864 non-null    object
#  6   mercado_principal    864 non-null    object
#  7   precio_min_mes       864 non-null    float64
#  8   precio_max_mes       864 non-null    float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 60.9+ KB

# %%
df_imagenes = pd.read_csv('datos/imagenes_metadata.csv')
df_imagenes.head()
# Out:
#             imagen_id       pais            region       fecha  \
# 0  SAT_FRA_202001_000    Francia  Región Principal  2020-01-15
# 1  SAT_ARG_202001_001  Argentina          Noroeste  2020-01-31
# 2  SAT_CHN_202003_002      China  Región Principal  2020-03-01
# 3  SAT_DEU_202003_003   Alemania  Región Principal  2020-03-12
# 4  SAT_FRA_202003_004    Francia  Región Principal  2020-03-22
#
#    indice_ndvi_promedio  indice_ndvi_min  indice_ndvi_max  indice_evi  \
# 0                 0.391            0.259            0.432       0.432
# 1                 0.488            0.390            0.601       0.555
# 2                 0.546            0.433            0.622       0.655
# 3                 0.601            0.446            0.655       0.744
# 4                 0.639            0.518            0.753       0.792
#
#   uso_suelo_predominante  humedad_suelo_estimada  cobertura_nubes  \
# 0                 bosque                   0.378            0.074
# ...

# %%
df_imagenes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   imagen_id               250 non-null    object
#  1   pais                    250 non-null    object
#  2   region                  250 non-null    object
#  3   fecha                   250 non-null    object
#  4   indice_ndvi_promedio    250 non-null    float64
#  5   indice_ndvi_min         250 non-null    float64
#  6   indice_ndvi_max         250 non-null    float64
#  7   indice_evi              250 non-null    float64
#  8   uso_suelo_predominante  250 non-null    object
#  9   humedad_suelo_estimada  250 non-null    float64
#  10  cobertura_nubes         250 non-null    float64
#  11  resolucion_metros       250 non-null    int64
#  12  satelite                250 non-null    object
#  13  bandas_disponibles      250 non-null    object
# ...

# %% [markdown]
# ### 2. Datos semi-estructurados

# %%
df_condiciones = pd.read_csv('datos/condiciones_climaticas.csv')
df_condiciones.head()
# Out:
#    anio codigo_iso  dias_con_heladas eventos_extremos  \
# 0  2011        ARG                19              NaN
# 1  2011        ARG                48              NaN
# 2  2011        ARG                86              NaN
# 3  2011        AUS                49              NaN
# 4  2011        AUS               100       inundacion
#
#    humedad_relativa_promedio  indice_aridez  meses_estres_hidrico       pais  \
# 0                         64          17.26                     1  Argentina
# 1                         82           8.63                     6  Argentina
# 2                         61          18.37                     7  Argentina
# 3                         59          12.24                     0  Australia
# 4                         82          10.64                     1  Australia
#
#    precipitacion_total         region_nombre  temperatura_maxima  \
# 0                 1050          Pampa Húmeda                22.3
# ...

# %%
df_condiciones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   anio                       260 non-null    int64
#  1   codigo_iso                 260 non-null    object
#  2   dias_con_heladas           260 non-null    int64
#  3   eventos_extremos           118 non-null    object
#  4   humedad_relativa_promedio  260 non-null    int64
#  5   indice_aridez              260 non-null    float64
#  6   meses_estres_hidrico       260 non-null    int64
#  7   pais                       260 non-null    object
#  8   precipitacion_total        260 non-null    int64
#  9   region_nombre              260 non-null    object
#  10  temperatura_maxima         260 non-null    float64
#  11  temperatura_minima         260 non-null    float64
#  12  temperatura_promedio       260 non-null    float64
# ...

# %%
df_politicas = pd.read_csv('datos/politicas_agricolas.csv')
df_politicas.head()
# Out:
#   codigo nombre_pais  acuerdo_internacional_anio_firma  \
# 0    ARG   Argentina                               NaN
# 1    ARG   Argentina                               NaN
# 2    ARG   Argentina                               NaN
# 3    ARG   Argentina                               NaN
# 4    ARG   Argentina                               NaN
#
#    acuerdo_internacional_firmado acuerdo_internacional_nombre  \
# 0                              0       Convenio_Biodiversidad
# 1                              0       Convenio_Biodiversidad
# 2                              0       Convenio_Biodiversidad
# 3                              0       Convenio_Biodiversidad
# 4                              0       Convenio_Biodiversidad
#
#    regulacion_anio_implementacion  regulacion_multa_hectarea  \
# 0                            2010                        NaN
# 1                            2010                        NaN
# 2                            2010                        NaN
# ...

# %%
df_politicas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 17 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   codigo                            159 non-null    object
#  1   nombre_pais                       159 non-null    object
#  2   acuerdo_internacional_anio_firma  95 non-null     float64
#  3   acuerdo_internacional_firmado     159 non-null    int64
#  4   acuerdo_internacional_nombre      159 non-null    object
#  5   regulacion_anio_implementacion    159 non-null    int64
#  6   regulacion_multa_hectarea         24 non-null     float64
#  7   regulacion_porcentaje_minimo      23 non-null     float64
#  8   regulacion_tipo                   159 non-null    object
#  9   regulacion_vigente                159 non-null    int64
#  10  subsidio_anio                     159 non-null    int64
# ...

# %% [markdown]
# ### 3. Datos no estructurados

# %%
df_noticias = pd.read_csv('datos/noticias_agricolas.csv')
df_noticias.head()
# Out:
#   id_noticia  Alemania  Argentina  Australia  Brasil  Canadá  España  \
# 0   NEWS6582         0          0          0       0       0       1
# 1   NEWS8516         0          0          0       0       0       1
# 2   NEWS9993         0          0          0       0       0       0
# 3   NEWS2701         0          0          0       0       0       0
# 4   NEWS2755         0          0          0       0       0       0
#
#    Estados Unidos  India  Italia  ...  China  categoria  \
# 0               0      0       1  ...      0      clima
# 1               0      0       0  ...      0      clima
# 2               0      0       1  ...      0      clima
# 3               0      0       0  ...      0      clima
# 4               0      0       0  ...      0   comercio
#
#                                            contenido   Año         Mes  Día  \
# 0  Eventos climáticos extremos están afectando la...  2021  septiembre   23
# ...

# %%
df_noticias.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_noticia        60 non-null     object
#  1   Alemania          60 non-null     int64
#  2   Argentina         60 non-null     int64
#  3   Australia         60 non-null     int64
#  4   Brasil            60 non-null     int64
#  5   Canadá            60 non-null     int64
#  6   España            60 non-null     int64
#  7   Estados Unidos    60 non-null     int64
#  8   India             60 non-null     int64
#  9   Italia            60 non-null     int64
#  10  Francia           60 non-null     int64
#  11  Kenia             60 non-null     int64
#  12  México            60 non-null     int64
#  13  Nueva Zelanda     60 non-null     int64
#  14  Rusia             60 non-null     int64
#  15  China             60 non-null     int64
# ...

# %%
df_reporte = pd.read_csv('datos/reporte_plagas.csv')
df_reporte.head()
# Out:
#     Año    Mes  Día  Area_afectada         Cultivo  Eficacia       Pais  \
# 0  2020  enero    1           2745           Arroz        93      China
# 1  2020  enero   13           3943  Caña de azúcar        97    Francia
# 2  2020  enero   15             10            Maíz        82     Brasil
# 3  2020  enero   18           3064            Maíz        83     Brasil
# 4  2020  enero   23            995            Soja        75  Argentina
#
#    Perdida_estimada       Plaga_detectada            Region Severidad  \
# 0                26  Barrenador del tallo  Región Principal     Media
# 1                17        Chinche marrón  Región Principal   Crítica
# 2                38  Oruga militar tardía           Cerrado      Alta
# 3                 3  Barrenador del tallo    Mata Atlántica   Crítica
# 4                 2              Langosta         Patagonia     Media
#
#                    Tratamiento_Aplicado
# 0               Químico (Epoxiconazole)
# ...

# %%
df_reporte.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Año                   100 non-null    int64
#  1   Mes                   100 non-null    object
#  2   Día                   100 non-null    int64
#  3   Area_afectada         100 non-null    int64
#  4   Cultivo               100 non-null    object
#  5   Eficacia              100 non-null    int64
#  6   Pais                  100 non-null    object
#  7   Perdida_estimada      100 non-null    int64
#  8   Plaga_detectada       100 non-null    object
#  9   Region                100 non-null    object
#  10  Severidad             100 non-null    object
#  11  Tratamiento_Aplicado  100 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 9.5+ KB
