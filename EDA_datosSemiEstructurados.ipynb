# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df_condiciones = pd.read_csv('datos/condiciones_climaticas.csv')
df_condiciones.head()
# Out:
#    anio codigo_iso  dias_con_heladas eventos_extremos  \
# 0  2011        ARG                19              NaN
# 1  2011        ARG                48              NaN
# 2  2011        ARG                86              NaN
# 3  2011        AUS                49              NaN
# 4  2011        AUS               100       inundacion
#
#    humedad_relativa_promedio  indice_aridez  meses_estres_hidrico       pais  \
# 0                         64          17.26                     1  Argentina
# 1                         82           8.63                     6  Argentina
# 2                         61          18.37                     7  Argentina
# 3                         59          12.24                     0  Australia
# 4                         82          10.64                     1  Australia
#
#    precipitacion_total         region_nombre  temperatura_maxima  \
# 0                 1050          Pampa Húmeda                22.3
# 1                  702                  Cuyo                34.6
# 2                  635             Patagonia                21.5
# 3                 1040  Murray-Darling Basin                33.9
# 4                  912      Queensland Coast                34.5
#
#    temperatura_minima  temperatura_promedio
# 0                 3.6                  16.9
# 1                 8.5                  22.6
# 2                 2.1                   9.6
# 3                18.1                  23.6
# 4                 9.3                  23.8

# %%
df_politicas = pd.read_csv('datos/politicas_agricolas.csv')
df_politicas.head()
# Out:
#   codigo nombre_pais  acuerdo_internacional_anio_firma  \
# 0    ARG   Argentina                               NaN
# 1    ARG   Argentina                               NaN
# 2    ARG   Argentina                               NaN
# 3    ARG   Argentina                               NaN
# 4    ARG   Argentina                               NaN
#
#    acuerdo_internacional_firmado acuerdo_internacional_nombre  \
# 0                              0       Convenio_Biodiversidad
# 1                              0       Convenio_Biodiversidad
# 2                              0       Convenio_Biodiversidad
# 3                              0       Convenio_Biodiversidad
# 4                              0       Convenio_Biodiversidad
#
#    regulacion_anio_implementacion  regulacion_multa_hectarea  \
# 0                            2010                        NaN
# 1                            2010                        NaN
# 2                            2010                        NaN
# 3                            2010                        NaN
# 4                            2012                        NaN
#
#    regulacion_porcentaje_minimo             regulacion_tipo  \
# 0                           NaN  pesticidas_neonicotinoides
# 1                           NaN  pesticidas_neonicotinoides
# 2                           NaN  pesticidas_neonicotinoides
# 3                           NaN  pesticidas_neonicotinoides
# 4                           NaN                    uso_agua
#
#    regulacion_vigente  subsidio_anio  subsidio_beneficiarios  \
# 0                   1           2019                    7215
# 1                   1           2021                    1914
# 2                   1           2021                   10823
# 3                   1           2023                   10898
# 4                   0           2019                    7215
#
#                         subsidio_descripcion subsidio_moneda  subsidio_monto  \
# 0     Subsidio para investigacion desarrollo             USD        15562206
# 1                   Subsidio para maquinaria             USD        25542386
# 2                Subsidio para fertilizantes             USD        32694726
# 3  Subsidio para expansion frontera agricola             USD        12595066
# 4     Subsidio para investigacion desarrollo             USD        15562206
#
#    subsidio_Precio_euros                subsidio_tipo
# 0            14317229.52     investigacion_desarrollo
# 1            23498995.12                   maquinaria
# 2            30079147.92                fertilizantes
# 3            11587460.72  expansion_frontera_agricola
# 4            14317229.52     investigacion_desarrollo

# %%
#Valores nulos que existen
df_condiciones.isnull().sum()
# Out:
# anio                           0
# codigo_iso                     0
# dias_con_heladas               0
# eventos_extremos             142
# humedad_relativa_promedio      0
# indice_aridez                  0
# meses_estres_hidrico           0
# pais                           0
# precipitacion_total            0
# region_nombre                  0
# temperatura_maxima             0
# temperatura_minima             0
# temperatura_promedio           0
# dtype: int64

# %% [markdown]
# En este caso la lectura de los nulos es correcta ya que en todas las condiciones climaticas no hay eventos extremos.

# %%
df_condiciones["eventos_extremos"] = df_condiciones["eventos_extremos"].fillna("sin evento")

# %%
df_politicas.isnull().sum()
# Out:
# codigo                                0
# nombre_pais                           0
# acuerdo_internacional_anio_firma     64
# acuerdo_internacional_firmado         0
# acuerdo_internacional_nombre          0
# regulacion_anio_implementacion        0
# regulacion_multa_hectarea           135
# regulacion_porcentaje_minimo        136
# regulacion_tipo                       0
# regulacion_vigente                    0
# subsidio_anio                         0
# subsidio_beneficiarios                0
# subsidio_descripcion                  0
# subsidio_moneda                       0
# subsidio_monto                        0
# subsidio_Precio_euros                 0
# subsidio_tipo                         0
# dtype: int64

# %% [markdown]
# Estos nulos son completamente normales ya que no todos los acuerdos estan firmados y por eso no presentan un año de firma y en el caso de la multa, no todos conllevan una sancion o un minimo de sancion

# %%
df_condiciones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   anio                       260 non-null    int64
#  1   codigo_iso                 260 non-null    object
#  2   dias_con_heladas           260 non-null    int64
#  3   eventos_extremos           260 non-null    object
#  4   humedad_relativa_promedio  260 non-null    int64
#  5   indice_aridez              260 non-null    float64
#  6   meses_estres_hidrico       260 non-null    int64
#  7   pais                       260 non-null    object
#  8   precipitacion_total        260 non-null    int64
#  9   region_nombre              260 non-null    object
#  10  temperatura_maxima         260 non-null    float64
#  11  temperatura_minima         260 non-null    float64
#  12  temperatura_promedio       260 non-null    float64
# dtypes: float64(4), int64(5), object(4)
# memory usage: 26.5+ KB

# %% [markdown]
# ## Análisis de eventos extremos

# %% [markdown]
# ### Frecuencia de eventos extremos por pais

# %%
# Rellenar nulos
df_condiciones["eventos_extremos"] = df_condiciones["eventos_extremos"].fillna("")

# %%
# Convertir a lista 
df_condiciones["eventos_extremos"] = df_condiciones["eventos_extremos"].apply(
    lambda x: x.replace("[", "").replace("]", "").replace("'", "").split(",")
)

# %%
df_condiciones["num_eventos"] = df_condiciones["eventos_extremos"].apply(len)

# %%
lista_eventos = []

for eventos in df_condiciones["eventos_extremos"]:
    for e in eventos:
        if e != "":
            lista_eventos.append(e)

df_eventos = pd.Series(lista_eventos).value_counts()

df_eventos
# Out:
# sin evento         142
# sequia_severa       19
# sequia_extrema      17
# helada_tardia       16
# tormenta_severa     13
# ola_calor           12
# inundacion          11
# incendios           11
# sequia_moderada     11
# granizo              8
# Name: count, dtype: int64

# %%
df_eventos.plot(kind="bar")
plt.title("Frecuencia de eventos extremos")
plt.xlabel("Evento")
plt.ylabel("Frecuencia")
plt.xticks(rotation=45)
plt.show()

# %%
df_exploded = df_condiciones.explode("eventos_extremos")

df_exploded = df_exploded[df_exploded["eventos_extremos"] != ""]

eventos_pais = df_exploded.groupby(["pais", "eventos_extremos"]).size().unstack(fill_value=0)

eventos_pais
# Out:
# eventos_extremos  granizo  helada_tardia  incendios  inundacion  ola_calor  \
# pais
# Alemania                0              0          0           0          1
# Argentina               1              3          1           0          3
# Australia               0              2          2           4          2
# Brasil                  0              2          3           1          0
# China                   0              1          0           1          0
# Estados Unidos          2              2          2           1          2
# Francia                 0              1          0           0          1
# India                   3              3          2           3          1
# Kenia                   2              2          0           1          1
# México                  0              0          1           0          1
#
# eventos_extremos  sequia_extrema  sequia_moderada  sequia_severa  sin evento  \
# pais
# Alemania                       0                0              1           9
# Argentina                      2                1              2          23
# Australia                      3                0              4          20
# Brasil                         4                1              2          20
# China                          0                0              1           8
# Estados Unidos                 3                1              2          23
# Francia                        0                2              0           8
# India                          3                5              3          18
# Kenia                          1                0              4           5
# México                         1                1              0           8
#
# eventos_extremos  tormenta_severa
# pais
# Alemania                        0
# Argentina                       0
# Australia                       2
# Brasil                          3
# China                           2
# Estados Unidos                  3
# Francia                         1
# India                           2
# Kenia                           0
# México                          0

# %%
eventos_pais.plot(kind="bar", stacked=True)
plt.title("Eventos extremos por país")
plt.xlabel("País")
plt.ylabel("Frecuencia")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# El análisis por país muestra una distribución desigual de eventos extremos. Países como India y Australia presentan una mayor frecuencia, lo que sugiere una mayor exposición a condiciones climáticas adversas.
#
# Por otro lado, países como Francia o China muestran menor incidencia de eventos extremos.
#
# En cuanto al tipo de eventos, predominan las sequías (en sus distintas intensidades) y las tormentas severas, lo que refuerza la importancia del estrés hídrico como factor clave en el sistema agrícola.

# %%
corr = df_condiciones[[
    "indice_aridez",
    "meses_estres_hidrico",
    "precipitacion_total"
]].corr()

corr
# Out:
#                       indice_aridez  meses_estres_hidrico  precipitacion_total
# indice_aridez              1.000000             -0.606511             0.793797
# meses_estres_hidrico      -0.606511              1.000000            -0.730566
# precipitacion_total        0.793797             -0.730566             1.000000

# %%
sns.heatmap(corr, annot=True)
plt.title("Matriz de correlación")
plt.show()

# %% [markdown]
# Se observa una fuerte ***correlación positiva*** (0.79) entre la precipitación total y el índice de aridez, lo que indica que a mayor precipitación, mejores condiciones hídricas en el suelo.
#
# Por otro lado, existe una ***correlación negativa significativa*** (-0.73) entre la precipitación total y los meses de estrés hídrico, lo que confirma que menores niveles de lluvia están asociados con periodos más prolongados de escasez de agua.
#
# Además, el índice de aridez presenta una ***correlación negativa moderada*** (-0.61) con los meses de estrés hídrico, reforzando la relación entre disponibilidad de agua y condiciones climáticas adversas.

# %% [markdown]
# - **Conclusion**:
#
# La alta frecuencia de eventos relacionados con sequías observada en los datos se alinea con las correlaciones obtenidas, donde la baja precipitación está directamente asociada con mayores periodos de estrés hídrico.
#
# Esto sugiere que las regiones con menor disponibilidad de agua no solo presentan peores indicadores climáticos, sino también una mayor vulnerabilidad a eventos extremos.

# %% [markdown]
# ### Impacto de políticas en producción

# %%
df_produccion = pd.read_csv("datos/produccion_agricola.csv")

df_produccion.head()
# Out:
#         pais codigo_iso           region  cultivo  anio  superficie_hectareas  \
# 0  Argentina        ARG  América del Sur     Soja  2011               4703643
# 1  Argentina        ARG  América del Sur     Maíz  2011               3371781
# 2  Argentina        ARG  América del Sur   Cebada  2011               1661577
# 3  Argentina        ARG  América del Sur       Té  2011                188518
# 4  Argentina        ARG  América del Sur  Algodón  2011               1638327
#
#    rendimiento_ton_ha  produccion_ton  fertilizantes_kg_ha  agua_riego_m3_ha  \
# 0                2.22        10465461                  105              4811
# 1                8.45        28485921                  164              5557
# 2                2.77         4596917                  105              6514
# 3                3.07          577886                  236              8527
# 4                1.18         1929756                  276              6925
#
#    tendencia_5_anios
# 0           0.000536
# 1           0.030943
# 2          -0.039779
# 3           0.003623
# 4           0.007735

# %%
df_produccion.columns
# Out:
# Index(['pais', 'codigo_iso', 'region', 'cultivo', 'anio',
#        'superficie_hectareas', 'rendimiento_ton_ha', 'produccion_ton',
#        'fertilizantes_kg_ha', 'agua_riego_m3_ha', 'tendencia_5_anios'],
#       dtype='object')

# %%
produccion_pais = df_produccion.groupby("pais")[[
    "produccion_ton",
    "rendimiento_ton_ha"
]].mean().reset_index()

produccion_pais
# Out:
#               pais  produccion_ton  rendimiento_ton_ha
# 0         Alemania    4.843421e+07           15.690500
# 1        Argentina    9.005145e+06            3.447750
# 2        Australia    7.651199e+07           15.902875
# 3           Brasil    7.733565e+07           14.666375
# 4           Canadá    9.482026e+06            3.461125
# 5            China    7.411340e+07           13.980250
# 6           España    6.273694e+07           13.182875
# 7   Estados Unidos    4.952174e+07           13.900125
# 8          Francia    5.016059e+07           12.315625
# 9            India    5.709305e+07           13.950000
# 10          Italia    6.346513e+07           15.191125
# 11           Kenia    5.331351e+07           13.896500
# 12          México    5.575588e+07           14.617000
# 13   Nueva Zelanda    4.052477e+07           13.295125
# 14           Rusia    7.200457e+07           15.679250

# %%
print(produccion_pais.columns.tolist())
# Out:
# ['pais', 'produccion_ton', 'rendimiento_ton_ha']

# %%
politicas_pais = df_politicas.groupby("nombre_pais").size().reset_index(name="num_politicas")

# %%
produccion_pais = produccion_pais.rename(columns={"pais": "nombre_pais"})

# %%
df_final = pd.merge(produccion_pais, politicas_pais, on="nombre_pais", how="inner")

df_final
# Out:
#        nombre_pais  produccion_ton  rendimiento_ton_ha  num_politicas
# 0         Alemania    4.843421e+07           15.690500             18
# 1        Argentina    9.005145e+06            3.447750             12
# 2        Australia    7.651199e+07           15.902875             12
# 3           Brasil    7.733565e+07           14.666375             27
# 4            China    7.411340e+07           13.980250              9
# 5           España    6.273694e+07           13.182875              6
# 6   Estados Unidos    4.952174e+07           13.900125             12
# 7          Francia    5.016059e+07           12.315625             24
# 8            India    5.709305e+07           13.950000             12
# 9            Kenia    5.331351e+07           13.896500              6
# 10          México    5.575588e+07           14.617000             12
# 11   Nueva Zelanda    4.052477e+07           13.295125              9

# %%
correlation_matrix = df_final[["num_politicas", "produccion_ton", "rendimiento_ton_ha"]].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Matriz de Correlación entre Políticas y Rendimiento')
plt.show()

# %% [markdown]
# Los resultados muestran una correlación **positiva débil** entre el número de políticas y la producción total (0.14), así como con el rendimiento agrícola (0.08).
#
# Esto indica que, aunque existe cierta relación, el número de políticas no es un factor determinante en el aumento de la producción o del rendimiento.
#
# Por otro lado, se observa una **fuerte correlación** entre la producción total y el rendimiento (0.81), lo que confirma la coherencia de los datos y la relación directa entre ambas variables.

# %% [markdown]
# - **Conclusion**:
#
# En conjunto, los resultados sugieren que las políticas agrícolas no tienen un impacto directo significativo en la producción, al menos en términos agregados por país.
#
# Esto puede deberse a que la producción agrícola depende de múltiples factores adicionales, como las condiciones climáticas, el tipo de cultivo o el nivel tecnológico.
#
# Por tanto, las políticas podrían estar orientadas más a la gestión y estabilización del sistema agrícola que a un aumento inmediato de la producción.

# %% [markdown]
# ## Integración contextual

# %% [markdown]
# ### Combinar políticas con datos de producción

# %%
# Total de ayudas económicas por país
subsidios_pais = df_politicas.groupby("nombre_pais")["subsidio_Precio_euros"].sum().reset_index()

subsidios_pais
# Out:
#        nombre_pais  subsidio_Precio_euros
# 0         Alemania           3.748127e+08
# 1        Argentina           2.384485e+08
# 2        Australia           2.136785e+08
# 3           Brasil           6.194276e+08
# 4            China           2.284530e+08
# 5           España           1.664452e+08
# 6   Estados Unidos           1.612560e+08
# 7          Francia           2.648442e+08
# 8            India           2.522220e+08
# 9            Kenia           1.598452e+08
# 10          México           2.896515e+08
# 11   Nueva Zelanda           1.324107e+08

# %%
produccion_pais = df_produccion.groupby("pais")[[
    "produccion_ton",
    "rendimiento_ton_ha"
]].mean().reset_index()

# %%
produccion_pais = produccion_pais.rename(columns={"pais": "nombre_pais"})

# %%
df_subsidios = pd.merge(produccion_pais, subsidios_pais, on="nombre_pais", how="inner")

df_subsidios
# Out:
#        nombre_pais  produccion_ton  rendimiento_ton_ha  subsidio_Precio_euros
# 0         Alemania    4.843421e+07           15.690500           3.748127e+08
# 1        Argentina    9.005145e+06            3.447750           2.384485e+08
# 2        Australia    7.651199e+07           15.902875           2.136785e+08
# 3           Brasil    7.733565e+07           14.666375           6.194276e+08
# 4            China    7.411340e+07           13.980250           2.284530e+08
# 5           España    6.273694e+07           13.182875           1.664452e+08
# 6   Estados Unidos    4.952174e+07           13.900125           1.612560e+08
# 7          Francia    5.016059e+07           12.315625           2.648442e+08
# 8            India    5.709305e+07           13.950000           2.522220e+08
# 9            Kenia    5.331351e+07           13.896500           1.598452e+08
# 10          México    5.575588e+07           14.617000           2.896515e+08
# 11   Nueva Zelanda    4.052477e+07           13.295125           1.324107e+08

# %% [markdown]
# El dataset resultante permite analizar de forma conjunta variables económicas (políticas) y productivas, facilitando la identificación de patrones y posibles relaciones entre ambas dimensiones.

# %% [markdown]
# ### Relacionar subsidios con incrementos de rendimiento

# %%
correlation_matrix = df_subsidios[["subsidio_Precio_euros", "rendimiento_ton_ha"]].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Matriz de Correlación entre Subsidio y Rendimiento')
plt.show()

# %% [markdown]
# Los resultados muestran una **correlación débil** (0.16) entre el volumen de subsidios y el rendimiento agrícola, lo que indica que una mayor inversión económica no implica necesariamente un incremento proporcional en la productividad.
#
# Esto sugiere que los subsidios, aunque importantes, no son el único factor determinante del rendimiento agrícola, ya que este depende también de condiciones climáticas, tecnología y gestión agrícola.

# %% [markdown]
# ## Prospección

# %% [markdown]
# ## Políticas

# %% [markdown]
# ### ¿Las políticas de subsidio tienen impacto medible en la producción?

# %%
df_politicas_cp = df_politicas

# %%
df_produccion_agricola = pd.read_csv("datos/produccion_agricola.csv")
df_produccion_ganadera = pd.read_csv("datos/produccion_ganadera.csv")

# %%
# Unificar producción 
df_produccion_ganadera['prod_total_gana'] = df_produccion_ganadera['produccion_carne_ton'] + df_produccion_ganadera['produccion_leche_lt']
df_prod = pd.merge(df_produccion_agricola[['pais', 'anio', 'produccion_ton']], 
                   df_produccion_ganadera[['pais', 'anio', 'prod_total_gana']], 
                   on=['pais', 'anio'])
df_prod['produccion_total'] = df_prod['produccion_ton'] + df_prod['prod_total_gana']

# %%
# Unimos con politicas
df_final = pd.merge(df_prod, 
                    df_politicas_cp[['nombre_pais', 'subsidio_anio', 'subsidio_monto']], 
                    left_on=['pais', 'anio'], 
                    right_on=['nombre_pais', 'subsidio_anio'])

# %%
# Dividimos el monto en 3 grupos iguales para poder comparar grupos
df_final['nivel_subsidio'] = pd.qcut(df_final['subsidio_monto'], 3, labels=['Bajo', 'Medio', 'Alto'])

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 6))
# Gráfico A: Regresión (¿Hay una tendencia clara?)
sns.regplot(ax=axes[0], data=df_final, x='subsidio_monto', y='produccion_total', 
            scatter_kws={'alpha':0.5}, line_kws={'color':'red'})
axes[0].set_title('Correlación: Monto de Subsidio vs Producción Total')

# Gráfico B: Comparativa de niveles (¿Produce más el que más recibe?)
sns.barplot(ax=axes[1], data=df_final, x='nivel_subsidio', y='produccion_total', palette='Blues')
axes[1].set_title('Producción Media según Nivel de Subsidio')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\puebl\AppData\Local\Temp\ipykernel_11424\204283705.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(ax=axes[1], data=df_final, x='nivel_subsidio', y='produccion_total', palette='Blues')

# %%
# RESULTADO
correlacion = df_final['subsidio_monto'].corr(df_final['produccion_total'])
print(f"La correlación entre el monto y la producción es de: {correlacion:.2f}")
# Out:
# La correlación entre el monto y la producción es de: 0.03

# %% [markdown]
# ### ¿Qué combinaciones de políticas son más efectivas?

# %%
# Unimos pero trayendo los "Tipos" de políticas
df_combos = pd.merge(df_prod, 
                    df_politicas[['nombre_pais', 'subsidio_anio', 'subsidio_tipo', 'regulacion_tipo', 'acuerdo_internacional_nombre']], 
                    left_on=['pais', 'anio'], 
                    right_on=['nombre_pais', 'subsidio_anio'])

# Creamos la Combinación
df_combos['combinacion'] = df_combos['subsidio_tipo'] + " + " + df_combos['regulacion_tipo']

# Calculamos la efectividad media por combinación
efectividad = df_combos.groupby('combinacion')['produccion_total'].mean().sort_values(ascending=False).reset_index()

# Gráfico de Efectividad
plt.figure(figsize=(12, 7))
sns.barplot(data=efectividad, x='produccion_total', y='combinacion', palette='viridis')
plt.title('Ranking de Efectividad: Combinaciones de Políticas', fontsize=15)
plt.xlabel('Producción Total Media (Toneladas)')
plt.ylabel('Mix de Políticas (Subsidio + Regulación)')
plt.show()
# Out:
# C:\Users\puebl\AppData\Local\Temp\ipykernel_11424\1329794211.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=efectividad, x='produccion_total', y='combinacion', palette='viridis')
